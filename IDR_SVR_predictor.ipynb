# %% [markdown]
# <a href="https://colab.research.google.com/github/KULL-Centre/_2023_Tesei_IDRome/blob/main/IDR_SVR_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Preliminary information:**
#
# This Colab notebook enables to predict the scaling exponent, $\nu$, and the conformational entropy per residue, $S_\text{conf}/N$, of an intrinsically disordered protein (IDP) or protein region (IDR) based on the amino acid sequence.
#
# Predictions are generated by a support vector regression (SVR) model [1], which was trained on simulations of all the IDPs and IDRs of the human proteome performed using the CALVADOS model [2].
#
# Amino acid sequences can be provided via (i) a single fasta file containing one or several entries, (ii) multiple fasta files, or (iii) pasting each sequence in separate input text boxes.
#
# <b><font color='#FA003F'>How to cite this notebook:</font></b> If you use the $\nu$ values generated by the SVR model, we ask you to cite Tesei, Trolle et al. [1].
# 1. G. Tesei, A. I. Trolle, N. Jonsson, J. Betz, F. E. Knudsen, F. Pesce, K. E. Johansson, K. Lindorff-Larsen __Conformational ensembles of the human intrinsically disordered proteome__ _Nature._ 2024 626:897–904 2023.05.08.539815 DOI: https://doi.org/10.1038/s41586-023-07004-5
# 2. G. Tesei and K. Lindorff-Larsen __Improved predictions of phase behaviour of intrinsically disordered proteins by tuning the interaction range [version 2; peer review: 2 approved]__ _Open Research Europe_ 2023 2(94) DOI: https://doi.org/10.12688/openreseurope.14967.2
# ---

# %%
#@title <b>Preliminary operations</b>
import subprocess
subprocess.run( 'pip install wget localcider==0.1.18'.split() )
subprocess.run('pip uninstall scikit-learn -y'.split())
subprocess.run('pip install -U scikit-learn'.split())
import numpy as np
import itertools
from localcider.sequenceParameters import SequenceParameters
import wget
import sys
import os
from joblib import dump, load
import pandas as pd
from google.colab import files
from ipywidgets import IntProgress
from IPython.display import display
from IPython.display import clear_output

def calc_seq_prop(seq,residues,Nc,Cc,Hc):
    seq = list(seq).copy()
    fasta_kappa = np.array(seq.copy())
    N = len(seq)
    r = residues.copy()

    # calculate properties that do not depend on charges
    fK = sum([seq.count(a) for a in ['K']])/N
    fR = sum([seq.count(a) for a in ['R']])/N
    fE = sum([seq.count(a) for a in ['E']])/N
    fD = sum([seq.count(a) for a in ['D']])/N
    faro = sum([seq.count(a) for a in ['W','Y','F']])/N
    mean_lambda = np.mean(r.loc[seq].lambdas)

    pairs = np.array(list(itertools.combinations(seq,2)))
    pairs_indices = np.array(list(itertools.combinations(range(N),2)))
    # calculate sequence separations
    ij_dist = np.diff(pairs_indices,axis=1).flatten().astype(float)
    # calculate lambda sums
    ll = r.lambdas.loc[pairs[:,0]].values+r.lambdas.loc[pairs[:,1]].values
    # calculate SHD
    beta = -1
    shd = np.sum(ll*np.power(np.abs(ij_dist),beta))/N

    # fix charges
    if Nc == 1:
        r.loc['X'] = r.loc[seq[0]]
        r.loc['X','q'] = r.loc[seq[0],'q'] + 1.
        seq[0] = 'X'
        if r.loc['X','q'] > 0:
            fasta_kappa[0] = 'K'
        else:
            fasta_kappa[0] = 'A'
    if Cc == 1:
        r.loc['Z'] = r.loc[seq[-1]]
        r.loc['Z','q'] = r.loc[seq[-1],'q'] - 1.
        seq[-1] = 'Z'
        if r.loc['Z','q'] < 0:
            fasta_kappa[-1] = 'D'
        else:
            fasta_kappa[-1] = 'A'
    if Hc < 0.5:
        r.loc['H', 'q'] = 0
        fasta_kappa[np.where(np.array(seq) == 'H')[0]] = 'A'
    elif Hc >= 0.5:
        r.loc['H', 'q'] = 1
        fasta_kappa[np.where(np.array(seq) == 'H')[0]] = 'K'

    # calculate properties that depend on charges
    pairs = np.array(list(itertools.combinations(seq,2)))
    # calculate charge products
    qq = r.q.loc[pairs[:,0]].values*r.q.loc[pairs[:,1]].values
    # calculate SCD
    scd = np.sum(qq*np.sqrt(ij_dist))/N
    SeqOb = SequenceParameters(''.join(fasta_kappa))
    kappa = SeqOb.get_kappa()
    fcr = r.q.loc[seq].abs().mean()
    ncpr = r.q.loc[seq].mean()

    return pd.Series(data=[fK,fR,fE,fD,faro,scd,shd,kappa,fcr,mean_lambda,ncpr],
                 index=['fK','fR','fE','fD','faro','SCD','SHD','kappa','FCR','mean_lambda','NCPR'])

aa = ['A','C','D','E','F','G','H','I','K','L','M','N','P','Q','R','S','T','V','W','Y']

url = 'https://github.com/KULL-Centre/_2023_Tesei_IDRome/blob/main'

if os.path.exists('svr_model_nu.joblib') == False:
    wget.download(url+'/svr_models/svr_model_nu.joblib?raw=true')
if os.path.exists('svr_model_SPR.joblib') == False:
    wget.download(url+'/svr_models/svr_model_SPR.joblib?raw=true')
if os.path.exists('residues.csv') == False:
    wget.download(url+'/md_simulations/data/residues.csv?raw=true')

model_nu = load('svr_model_nu.joblib')
model_spr = load('svr_model_SPR.joblib')
features_nu = ['SCD','SHD','kappa','FCR','mean_lambda']
features_spr = ['SCD','SHD','mean_lambda']

residues = pd.read_csv('residues.csv')
residues = residues.set_index('one')

fasta_dict = {}
df = pd.DataFrame(columns=['nuSVR','SconfSVR/N (kB)','mean_lambda','SHD','SCD','kappa','FCR','NCPR',
                           'fK','fR','fE','fD','faro'])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator SVR from version 1.0.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
import pandas as pd

# Read your sequences from text file
with open('all_sequence_SOPA_9aa.txt', 'r') as f:
    sequences = [line.strip() for line in f if line.strip()]

# Create a dataframe with just the sequences
df = pd.DataFrame({
    'seq_name': [f'Seq_{i+1}' for i in range(len(sequences))],
    'fasta': sequences
})

# Save as CSV
df.to_csv('all_sequence_SOPA_9aa.csv', index=False)

# %%
# Initialize a dictionary to store FASTA sequences
fasta_dict = {}
current_upload = []

# Open and read the CSV file
with open('all_sequence_SOPA_9aa.csv', 'r') as f:
    # First, check if this is a CSV with headers by looking at the first line
    first_line = f.readline().strip()

    # Reset file pointer to beginning
    f.seek(0)

    # If it's a CSV with headers (like IDRome_DB.csv)
    if ',' in first_line:
        import pandas as pd
        df = pd.read_csv('all_sequence_SOPA_9aa.csv')

        # Check if 'fasta' column exists
        if 'fasta' in df.columns:
            for index, row in df.iterrows():
                seq_name = row.get('seq_name', f'Seq_{index}')
                fasta_dict[seq_name] = row['fasta']
                current_upload.append(seq_name)
        else:
            # If no 'fasta' column, assume the first column contains sequences
            column_name = df.columns[0]
            for index, row in df.iterrows():
                seq_name = f'Seq_{index}'
                fasta_dict[seq_name] = row[column_name]
                current_upload.append(seq_name)
    else:
        # If the file is a simple list of sequences, one per line
        for i, line in enumerate(f):
            line = line.strip()
            if line:  # Skip empty lines
                seq_name = f'Seq_{i+1}'
                fasta_dict[seq_name] = line
                current_upload.append(seq_name)

# Check sequences
for name in current_upload:
    sequence = fasta_dict[name]
    valid_aa = set("ACDEFGHIKLMNPQRSTVWY")
    if not all(aa in valid_aa for aa in sequence):
        print(f"Warning: Sequence {name} contains invalid amino acid characters!")
    else:
        print(f"Sequence {name} is valid with length {len(sequence)}")

print(f"Loaded {len(current_upload)} sequences")
# Out:
# Sequence Seq_1 is valid with length 9
# Sequence Seq_2 is valid with length 9
# Sequence Seq_3 is valid with length 9
# Sequence Seq_4 is valid with length 9
# Sequence Seq_5 is valid with length 9
# Sequence Seq_6 is valid with length 9
# Sequence Seq_7 is valid with length 9
# Sequence Seq_8 is valid with length 9
# Sequence Seq_9 is valid with length 9
# Sequence Seq_10 is valid with length 9
# Sequence Seq_11 is valid with length 9
# Sequence Seq_12 is valid with length 9
# Sequence Seq_13 is valid with length 9
# Sequence Seq_14 is valid with length 9
# Sequence Seq_15 is valid with length 9
# Sequence Seq_16 is valid with length 9
# Sequence Seq_17 is valid with length 9
# Sequence Seq_18 is valid with length 9
# Sequence Seq_19 is valid with length 9
# Sequence Seq_20 is valid with length 9
# Sequence Seq_21 is valid with length 9
# Sequence Seq_22 is valid with length 9
# Sequence Seq_23 is valid with length 9
# Sequence Seq_24 is valid with length 9
# Sequence Seq_25 is valid with length 9
# Sequence Seq_26 is valid with length 9
# Sequence Seq_27 is valid with length 9
# Sequence Seq_28 is valid with length 9
# Sequence Seq_29 is valid with length 9
# Sequence Seq_30 is valid with length 9
# Sequence Seq_31 is valid with length 9
# Sequence Seq_32 is valid with length 9
# Sequence Seq_33 is valid with length 9
# Sequence Seq_34 is valid with length 9
# Sequence Seq_35 is valid with length 9
# Sequence Seq_36 is valid with length 9
# Sequence Seq_37 is valid with length 9
# Sequence Seq_38 is valid with length 9
# Sequence Seq_39 is valid with length 9
# Sequence Seq_40 is valid with length 9
# Sequence Seq_41 is valid with length 9
# Sequence Seq_42 is valid with length 9
# Sequence Seq_43 is valid with length 9
# Sequence Seq_44 is valid with length 9
# Sequence Seq_45 is valid with length 9
# Sequence Seq_46 is valid with length 9
# Sequence Seq_47 is valid with length 9
# Sequence Seq_48 is valid with length 9
# Sequence Seq_49 is valid with length 9
# Sequence Seq_50 is valid with length 9
# Sequence Seq_51 is valid with length 9
# Sequence Seq_52 is valid with length 9
# Sequence Seq_53 is valid with length 9
# Sequence Seq_54 is valid with length 9
# Sequence Seq_55 is valid with length 9
# Sequence Seq_56 is valid with length 9
# Sequence Seq_57 is valid with length 9
# Sequence Seq_58 is valid with length 9
# Sequence Seq_59 is valid with length 9
# Sequence Seq_60 is valid with length 9
# Sequence Seq_61 is valid with length 9
# Sequence Seq_62 is valid with length 9
# Sequence Seq_63 is valid with length 9
# Sequence Seq_64 is valid with length 9
# Sequence Seq_65 is valid with length 9
# Sequence Seq_66 is valid with length 9
# Sequence Seq_67 is valid with length 9
# Sequence Seq_68 is valid with length 9
# Sequence Seq_69 is valid with length 9
# Sequence Seq_70 is valid with length 9
# Sequence Seq_71 is valid with length 9
# Sequence Seq_72 is valid with length 9
# Sequence Seq_73 is valid with length 9
# Sequence Seq_74 is valid with length 9
# Sequence Seq_75 is valid with length 9
# Sequence Seq_76 is valid with length 9
# Sequence Seq_77 is valid with length 9
# Sequence Seq_78 is valid with length 9
# Sequence Seq_79 is valid with length 9
# Sequence Seq_80 is valid with length 9
# Sequence Seq_81 is valid with length 9
# Sequence Seq_82 is valid with length 9
# Sequence Seq_83 is valid with length 9
# Sequence Seq_84 is valid with length 9
# Sequence Seq_85 is valid with length 9
# Sequence Seq_86 is valid with length 9
# Sequence Seq_87 is valid with length 9
# Sequence Seq_88 is valid with length 9
# Sequence Seq_89 is valid with length 9
# Sequence Seq_90 is valid with length 9
# Sequence Seq_91 is valid with length 9
# Sequence Seq_92 is valid with length 9
# Sequence Seq_93 is valid with length 9
# Sequence Seq_94 is valid with length 9
# Sequence Seq_95 is valid with length 9
# Sequence Seq_96 is valid with length 9
# Sequence Seq_97 is valid with length 9
# Sequence Seq_98 is valid with length 9
# Sequence Seq_99 is valid with length 9
# Sequence Seq_100 is valid with length 9
# Sequence Seq_101 is valid with length 9
# Sequence Seq_102 is valid with length 9
# Sequence Seq_103 is valid with length 9
# Sequence Seq_104 is valid with length 9
# Sequence Seq_105 is valid with length 9
# Sequence Seq_106 is valid with length 9
# Sequence Seq_107 is valid with length 9
# Sequence Seq_108 is valid with length 9
# Sequence Seq_109 is valid with length 9
# Sequence Seq_110 is valid with length 9
# Sequence Seq_111 is valid with length 9
# Sequence Seq_112 is valid with length 9
# Sequence Seq_113 is valid with length 9
# Sequence Seq_114 is valid with length 9
# Sequence Seq_115 is valid with length 9
# Sequence Seq_116 is valid with length 9
# Sequence Seq_117 is valid with length 9
# Sequence Seq_118 is valid with length 9
# Sequence Seq_119 is valid with length 9
# Sequence Seq_120 is valid with length 9
# Sequence Seq_121 is valid with length 9
# Sequence Seq_122 is valid with length 9
# Sequence Seq_123 is valid with length 9
# Sequence Seq_124 is valid with length 9
# Sequence Seq_125 is valid with length 9
# Sequence Seq_126 is valid with length 9
# Sequence Seq_127 is valid with length 9
# Sequence Seq_128 is valid with length 9
# Sequence Seq_129 is valid with length 9
# Sequence Seq_130 is valid with length 9
# Sequence Seq_131 is valid with length 9
# Sequence Seq_132 is valid with length 9
# Sequence Seq_133 is valid with length 9
# Sequence Seq_134 is valid with length 9
# Sequence Seq_135 is valid with length 9
# Sequence Seq_136 is valid with length 9
# Sequence Seq_137 is valid with length 9
# Sequence Seq_138 is valid with length 9
# Sequence Seq_139 is valid with length 9
# Sequence Seq_140 is valid with length 9
# Sequence Seq_141 is valid with length 9
# Sequence Seq_142 is valid with length 9
# Sequence Seq_143 is valid with length 9
# Sequence Seq_144 is valid with length 9
# Sequence Seq_145 is valid with length 9
# Sequence Seq_146 is valid with length 9
# Sequence Seq_147 is valid with length 9
# Sequence Seq_148 is valid with length 9
# Sequence Seq_149 is valid with length 9
# Sequence Seq_150 is valid with length 9
# Sequence Seq_151 is valid with length 9
# Sequence Seq_152 is valid with length 9
# Sequence Seq_153 is valid with length 9
# Sequence Seq_154 is valid with length 9
# Sequence Seq_155 is valid with length 9
# Sequence Seq_156 is valid with length 9
# Sequence Seq_157 is valid with length 9
# Sequence Seq_158 is valid with length 9
# Sequence Seq_159 is valid with length 9
# Sequence Seq_160 is valid with length 9
# Sequence Seq_161 is valid with length 9
# Sequence Seq_162 is valid with length 9
# Sequence Seq_163 is valid with length 9
# Sequence Seq_164 is valid with length 9
# Sequence Seq_165 is valid with length 9
# Sequence Seq_166 is valid with length 9
# Sequence Seq_167 is valid with length 9
# Sequence Seq_168 is valid with length 9
# Sequence Seq_169 is valid with length 9
# Sequence Seq_170 is valid with length 9
# Sequence Seq_171 is valid with length 9
# Sequence Seq_172 is valid with length 9
# Sequence Seq_173 is valid with length 9
# Sequence Seq_174 is valid with length 9
# Sequence Seq_175 is valid with length 9
# Sequence Seq_176 is valid with length 9
# Sequence Seq_177 is valid with length 9
# Sequence Seq_178 is valid with length 9
# Sequence Seq_179 is valid with length 9
# Sequence Seq_180 is valid with length 9
# Sequence Seq_181 is valid with length 9
# Sequence Seq_182 is valid with length 9
# Sequence Seq_183 is valid with length 9
# Sequence Seq_184 is valid with length 9
# Sequence Seq_185 is valid with length 9
# Sequence Seq_186 is valid with length 9
# Sequence Seq_187 is valid with length 9
# Sequence Seq_188 is valid with length 9
# Sequence Seq_189 is valid with length 9
# Sequence Seq_190 is valid with length 9
# Sequence Seq_191 is valid with length 9
# Sequence Seq_192 is valid with length 9
# Sequence Seq_193 is valid with length 9
# Sequence Seq_194 is valid with length 9
# Sequence Seq_195 is valid with length 9
# Sequence Seq_196 is valid with length 9
# Sequence Seq_197 is valid with length 9
# Sequence Seq_198 is valid with length 9
# Sequence Seq_199 is valid with length 9
# Sequence Seq_200 is valid with length 9
# Sequence Seq_201 is valid with length 9
# Sequence Seq_202 is valid with length 9
# Sequence Seq_203 is valid with length 9
# Sequence Seq_204 is valid with length 9
# Sequence Seq_205 is valid with length 9
# Sequence Seq_206 is valid with length 9
# Sequence Seq_207 is valid with length 9
# Sequence Seq_208 is valid with length 9
# Sequence Seq_209 is valid with length 9
# Sequence Seq_210 is valid with length 9
# Sequence Seq_211 is valid with length 9
# Sequence Seq_212 is valid with length 9
# Sequence Seq_213 is valid with length 9
# Sequence Seq_214 is valid with length 9
# Sequence Seq_215 is valid with length 9
# Sequence Seq_216 is valid with length 9
# Sequence Seq_217 is valid with length 9
# Sequence Seq_218 is valid with length 9
# Sequence Seq_219 is valid with length 9
# Sequence Seq_220 is valid with length 9
# Sequence Seq_221 is valid with length 9
# Sequence Seq_222 is valid with length 9
# Sequence Seq_223 is valid with length 9
# Sequence Seq_224 is valid with length 9
# Sequence Seq_225 is valid with length 9
# Sequence Seq_226 is valid with length 9
# Sequence Seq_227 is valid with length 9
# Sequence Seq_228 is valid with length 9
# Sequence Seq_229 is valid with length 9
# Sequence Seq_230 is valid with length 9
# Sequence Seq_231 is valid with length 9
# Sequence Seq_232 is valid with length 9
# Sequence Seq_233 is valid with length 9
# Sequence Seq_234 is valid with length 9
# Sequence Seq_235 is valid with length 9
# Sequence Seq_236 is valid with length 9
# Sequence Seq_237 is valid with length 9
# Sequence Seq_238 is valid with length 9
# Sequence Seq_239 is valid with length 9
# Sequence Seq_240 is valid with length 9
# Sequence Seq_241 is valid with length 9
# Sequence Seq_242 is valid with length 9
# Sequence Seq_243 is valid with length 9
# Sequence Seq_244 is valid with length 9
# Sequence Seq_245 is valid with length 9
# Sequence Seq_246 is valid with length 9
# Sequence Seq_247 is valid with length 9
# Sequence Seq_248 is valid with length 9
# Sequence Seq_249 is valid with length 9
# Sequence Seq_250 is valid with length 9
# Sequence Seq_251 is valid with length 9
# Sequence Seq_252 is valid with length 9
# Sequence Seq_253 is valid with length 9
# Sequence Seq_254 is valid with length 9
# Sequence Seq_255 is valid with length 9
# Sequence Seq_256 is valid with length 9
# Sequence Seq_257 is valid with length 9
# Sequence Seq_258 is valid with length 9
# Sequence Seq_259 is valid with length 9
# Sequence Seq_260 is valid with length 9
# Sequence Seq_261 is valid with length 9
# Sequence Seq_262 is valid with length 9
# Sequence Seq_263 is valid with length 9
# Sequence Seq_264 is valid with length 9
# Sequence Seq_265 is valid with length 9
# Sequence Seq_266 is valid with length 9
# Sequence Seq_267 is valid with length 9
# Sequence Seq_268 is valid with length 9
# Sequence Seq_269 is valid with length 9
# Sequence Seq_270 is valid with length 9
# Sequence Seq_271 is valid with length 9
# Sequence Seq_272 is valid with length 9
# Sequence Seq_273 is valid with length 9
# Sequence Seq_274 is valid with length 9
# Sequence Seq_275 is valid with length 9
# Sequence Seq_276 is valid with length 9
# Sequence Seq_277 is valid with length 9
# Sequence Seq_278 is valid with length 9
# Sequence Seq_279 is valid with length 9
# Sequence Seq_280 is valid with length 9
# Sequence Seq_281 is valid with length 9
# Sequence Seq_282 is valid with length 9
# Sequence Seq_283 is valid with length 9
# Sequence Seq_284 is valid with length 9
# Sequence Seq_285 is valid with length 9
# Sequence Seq_286 is valid with length 9
# Sequence Seq_287 is valid with length 9
# Sequence Seq_288 is valid with length 9
# Sequence Seq_289 is valid with length 9
# Sequence Seq_290 is valid with length 9
# Sequence Seq_291 is valid with length 9
# Sequence Seq_292 is valid with length 9
# Sequence Seq_293 is valid with length 9
# Sequence Seq_294 is valid with length 9
# Sequence Seq_295 is valid with length 9
# Sequence Seq_296 is valid with length 9
# Sequence Seq_297 is valid with length 9
# Sequence Seq_298 is valid with length 9
# Sequence Seq_299 is valid with length 9
# Sequence Seq_300 is valid with length 9
# Sequence Seq_301 is valid with length 9
# Sequence Seq_302 is valid with length 9
# Sequence Seq_303 is valid with length 9
# Sequence Seq_304 is valid with length 9
# Sequence Seq_305 is valid with length 9
# Sequence Seq_306 is valid with length 9
# Sequence Seq_307 is valid with length 9
# Sequence Seq_308 is valid with length 9
# Sequence Seq_309 is valid with length 9
# Sequence Seq_310 is valid with length 9
# Sequence Seq_311 is valid with length 9
# Sequence Seq_312 is valid with length 9
# Sequence Seq_313 is valid with length 9
# Sequence Seq_314 is valid with length 9
# Sequence Seq_315 is valid with length 9
# Sequence Seq_316 is valid with length 9
# Sequence Seq_317 is valid with length 9
# Sequence Seq_318 is valid with length 9
# Sequence Seq_319 is valid with length 9
# Sequence Seq_320 is valid with length 9
# Sequence Seq_321 is valid with length 9
# Sequence Seq_322 is valid with length 9
# Sequence Seq_323 is valid with length 9
# Sequence Seq_324 is valid with length 9
# Sequence Seq_325 is valid with length 9
# Sequence Seq_326 is valid with length 9
# Sequence Seq_327 is valid with length 9
# Sequence Seq_328 is valid with length 9
# Sequence Seq_329 is valid with length 9
# Sequence Seq_330 is valid with length 9
# Sequence Seq_331 is valid with length 9
# Sequence Seq_332 is valid with length 9
# Sequence Seq_333 is valid with length 9
# Sequence Seq_334 is valid with length 9
# Sequence Seq_335 is valid with length 9
# Sequence Seq_336 is valid with length 9
# Sequence Seq_337 is valid with length 9
# Sequence Seq_338 is valid with length 9
# Sequence Seq_339 is valid with length 9
# Sequence Seq_340 is valid with length 9
# Sequence Seq_341 is valid with length 9
# Sequence Seq_342 is valid with length 9
# Sequence Seq_343 is valid with length 9
# Sequence Seq_344 is valid with length 9
# Sequence Seq_345 is valid with length 9
# Sequence Seq_346 is valid with length 9
# Sequence Seq_347 is valid with length 9
# Sequence Seq_348 is valid with length 9
# Sequence Seq_349 is valid with length 9
# Sequence Seq_350 is valid with length 9
# Sequence Seq_351 is valid with length 9
# Sequence Seq_352 is valid with length 9
# Sequence Seq_353 is valid with length 9
# Sequence Seq_354 is valid with length 9
# Sequence Seq_355 is valid with length 9
# Sequence Seq_356 is valid with length 9
# Sequence Seq_357 is valid with length 9
# Sequence Seq_358 is valid with length 9
# Sequence Seq_359 is valid with length 9
# Sequence Seq_360 is valid with length 9
# Sequence Seq_361 is valid with length 9
# Sequence Seq_362 is valid with length 9
# Sequence Seq_363 is valid with length 9
# Sequence Seq_364 is valid with length 9
# Sequence Seq_365 is valid with length 9
# Sequence Seq_366 is valid with length 9
# Sequence Seq_367 is valid with length 9
# Sequence Seq_368 is valid with length 9
# Sequence Seq_369 is valid with length 9
# Sequence Seq_370 is valid with length 9
# Sequence Seq_371 is valid with length 9
# Sequence Seq_372 is valid with length 9
# Sequence Seq_373 is valid with length 9
# Sequence Seq_374 is valid with length 9
# Sequence Seq_375 is valid with length 9
# Sequence Seq_376 is valid with length 9
# Sequence Seq_377 is valid with length 9
# Sequence Seq_378 is valid with length 9
# Sequence Seq_379 is valid with length 9
# Sequence Seq_380 is valid with length 9
# Sequence Seq_381 is valid with length 9
# Sequence Seq_382 is valid with length 9
# Sequence Seq_383 is valid with length 9
# Sequence Seq_384 is valid with length 9
# Sequence Seq_385 is valid with length 9
# Sequence Seq_386 is valid with length 9
# Sequence Seq_387 is valid with length 9
# Sequence Seq_388 is valid with length 9
# Sequence Seq_389 is valid with length 9
# Sequence Seq_390 is valid with length 9
# Sequence Seq_391 is valid with length 9
# Sequence Seq_392 is valid with length 9
# Sequence Seq_393 is valid with length 9
# Sequence Seq_394 is valid with length 9
# Sequence Seq_395 is valid with length 9
# Sequence Seq_396 is valid with length 9
# Sequence Seq_397 is valid with length 9
# Sequence Seq_398 is valid with length 9
# Sequence Seq_399 is valid with length 9
# Sequence Seq_400 is valid with length 9
# Sequence Seq_401 is valid with length 9
# Sequence Seq_402 is valid with length 9
# Sequence Seq_403 is valid with length 9
# Sequence Seq_404 is valid with length 9
# Sequence Seq_405 is valid with length 9
# Sequence Seq_406 is valid with length 9
# Sequence Seq_407 is valid with length 9
# Sequence Seq_408 is valid with length 9
# Sequence Seq_409 is valid with length 9
# Sequence Seq_410 is valid with length 9
# Sequence Seq_411 is valid with length 9
# Sequence Seq_412 is valid with length 9
# Sequence Seq_413 is valid with length 9
# Sequence Seq_414 is valid with length 9
# Sequence Seq_415 is valid with length 9
# Sequence Seq_416 is valid with length 9
# Sequence Seq_417 is valid with length 9
# Sequence Seq_418 is valid with length 9
# Sequence Seq_419 is valid with length 9
# Sequence Seq_420 is valid with length 9
# Sequence Seq_421 is valid with length 9
# Sequence Seq_422 is valid with length 9
# Sequence Seq_423 is valid with length 9
# Sequence Seq_424 is valid with length 9
# Sequence Seq_425 is valid with length 9
# Sequence Seq_426 is valid with length 9
# Sequence Seq_427 is valid with length 9
# Sequence Seq_428 is valid with length 9
# Sequence Seq_429 is valid with length 9
# Sequence Seq_430 is valid with length 9
# Sequence Seq_431 is valid with length 9
# Sequence Seq_432 is valid with length 9
# Sequence Seq_433 is valid with length 9
# Sequence Seq_434 is valid with length 9
# Sequence Seq_435 is valid with length 9
# Sequence Seq_436 is valid with length 9
# Sequence Seq_437 is valid with length 9
# Sequence Seq_438 is valid with length 9
# Sequence Seq_439 is valid with length 9
# Sequence Seq_440 is valid with length 9
# Sequence Seq_441 is valid with length 9
# Sequence Seq_442 is valid with length 9
# Sequence Seq_443 is valid with length 9
# Sequence Seq_444 is valid with length 9
# Sequence Seq_445 is valid with length 9
# Sequence Seq_446 is valid with length 9
# Sequence Seq_447 is valid with length 9
# Sequence Seq_448 is valid with length 9
# Sequence Seq_449 is valid with length 9
# Sequence Seq_450 is valid with length 9
# Sequence Seq_451 is valid with length 9
# Sequence Seq_452 is valid with length 9
# Sequence Seq_453 is valid with length 9
# Sequence Seq_454 is valid with length 9
# Sequence Seq_455 is valid with length 9
# Sequence Seq_456 is valid with length 9
# Sequence Seq_457 is valid with length 9
# Sequence Seq_458 is valid with length 9
# Sequence Seq_459 is valid with length 9
# Sequence Seq_460 is valid with length 9
# Sequence Seq_461 is valid with length 9
# Sequence Seq_462 is valid with length 9
# Sequence Seq_463 is valid with length 9
# Sequence Seq_464 is valid with length 9
# Sequence Seq_465 is valid with length 9
# Sequence Seq_466 is valid with length 9
# Sequence Seq_467 is valid with length 9
# Sequence Seq_468 is valid with length 9
# Sequence Seq_469 is valid with length 9
# Sequence Seq_470 is valid with length 9
# Sequence Seq_471 is valid with length 9
# Sequence Seq_472 is valid with length 9
# Sequence Seq_473 is valid with length 9
# Sequence Seq_474 is valid with length 9
# Sequence Seq_475 is valid with length 9
# Sequence Seq_476 is valid with length 9
# Sequence Seq_477 is valid with length 9
# Sequence Seq_478 is valid with length 9
# Sequence Seq_479 is valid with length 9
# Sequence Seq_480 is valid with length 9
# Sequence Seq_481 is valid with length 9
# Sequence Seq_482 is valid with length 9
# Sequence Seq_483 is valid with length 9
# Sequence Seq_484 is valid with length 9
# Sequence Seq_485 is valid with length 9
# Sequence Seq_486 is valid with length 9
# Sequence Seq_487 is valid with length 9
# Sequence Seq_488 is valid with length 9
# Sequence Seq_489 is valid with length 9
# Sequence Seq_490 is valid with length 9
# Sequence Seq_491 is valid with length 9
# Sequence Seq_492 is valid with length 9
# Sequence Seq_493 is valid with length 9
# Sequence Seq_494 is valid with length 9
# Sequence Seq_495 is valid with length 9
# Sequence Seq_496 is valid with length 9
# Sequence Seq_497 is valid with length 9
# Sequence Seq_498 is valid with length 9
# Sequence Seq_499 is valid with length 9
# Sequence Seq_500 is valid with length 9
# Loaded 500 sequences

# %%
#@title <b>Input sequence(s)</b>
#@markdown Or paste a sequence and provide a name. This cell can be executed multiple times to register more sequences.
NAME = "" #@param {type:"string"}
SEQUENCE = "" #@param {type:"string"}

if NAME != "" and SEQUENCE != "":
    if " " in SEQUENCE:
        SEQUENCE = ''.join(SEQUENCE.split())
    fasta_dict[NAME] = SEQUENCE

    #check sequence
    for a in fasta_dict[NAME]:
        if a not in aa:
            print('WARNING: {} sequence contains a character not recognized as an aminoacid. This sequence will be ignored'.format(name))
            del fasta_dict[NAME]

else:
    print('No NAME and/or SEQUENCE provided. Upload fasta files with the cell above or paste a sequence at the time here.')

# %%
#@title <b>Define charge states</b>
#@markdown Define charge states:
charged_N_terminal_amine = False #@param {type:"boolean"}
charged_C_terminal_carboxyl = True #@param {type:"boolean"}
charged_histidine = True #@param {type:"boolean"}
Nc = 1 if charged_N_terminal_amine == True else 0
Cc = 1 if charged_C_terminal_carboxyl == True else 0

if charged_histidine == True:
    print('Define pH and pKa to set the charge of Histidines according to the Henderson-Hasselbalch equation.')
    pH = input('Enter pH value: ')
    pH = float(pH)
    pKa = input('Enter pKa value: ')
    pKa = float(pKa)
    Hc = 1/(1+10**(pH-pKa))
if charged_histidine == False:
    Hc = 0
# Out:
# Define pH and pKa to set the charge of Histidines according to the Henderson-Hasselbalch equation.
# Enter pH value: 7
# Enter pKa value: 7

# %%
#@title <b>Predict $\nu$ and $S_\text{conf}/N$
#@markdown Use this cell to calculate sequence features and predict the scaling exponent, $\nu$, and the conformational entropy per residue, $S_\text{conf}/N$. Results will be downloaded in a csv file.

f = IntProgress(min=0, max=len(fasta_dict), description='Progress:', bar_style='warning')
display(f)

for k in fasta_dict.keys():
    res = calc_seq_prop(fasta_dict[k],residues,Nc,Cc,Hc)
    nu = np.around(model_nu.predict(res.loc[features_nu].values.reshape(1, -1))[0],3)
    spr = np.around(model_spr.predict(res.loc[features_spr].values.reshape(1, -1))[0],3)
    df.loc[k,'nuSVR'] = nu
    df.loc[k,'SconfSVR/N (kB)'] = spr
    df.loc[k,res.index.values] = np.around(res.loc[res.index.values].values,3)
    f.value += 1

clear_output()
df.to_csv('svr_pred.csv',index_label='name')
files.download('svr_pred.csv')

df
# Out:
#         seq_name      fasta  nuSVR  SconfSVR/N (kB)   fK   fR     fE     fD  \
# 0          Seq_1  VTLAERLAG    NaN              NaN  NaN  NaN    NaN    NaN
# 1          Seq_2  GAAAAAAAA    NaN              NaN  NaN  NaN    NaN    NaN
# 2          Seq_3  EELVEEVLG    NaN              NaN  NaN  NaN    NaN    NaN
# 3          Seq_4  DAEAAADAA    NaN              NaN  NaN  NaN    NaN    NaN
# 4          Seq_5  VVTDASKVK    NaN              NaN  NaN  NaN    NaN    NaN
# ...          ...        ...    ...              ...  ...  ...    ...    ...
# Seq_496      NaN        NaN  0.615           10.691  0.0  0.0  0.000  0.000
# Seq_497      NaN        NaN  0.608           10.750  0.0  0.0  0.222  0.000
# Seq_498      NaN        NaN  0.649           10.847  0.0  0.0  0.222  0.333
# Seq_499      NaN        NaN  0.612           10.670  0.0  0.0  0.000  0.111
# Seq_500      NaN        NaN  0.610           10.719  0.0  0.0  0.000  0.000
#
#           faro    SCD    SHD  kappa    FCR  mean_lambda   NCPR
# 0          NaN    NaN    NaN    NaN    NaN          NaN    NaN
# 1          NaN    NaN    NaN    NaN    NaN          NaN    NaN
# 2          NaN    NaN    NaN    NaN    NaN          NaN    NaN
# 3          NaN    NaN    NaN    NaN    NaN          NaN    NaN
# 4          NaN    NaN    NaN    NaN    NaN          NaN    NaN
# ...        ...    ...    ...    ...    ...          ...    ...
# Seq_496  0.111  0.000  1.422  1.000  0.111        0.381 -0.111
# Seq_497  0.000  0.461  0.875  0.531  0.333        0.244 -0.333
# Seq_498  0.111  2.899  0.939  0.101  0.667        0.242 -0.667
# Seq_499  0.000  0.314  1.802  0.868  0.222        0.484 -0.222
# Seq_500  0.000  0.000  1.003  1.000  0.111        0.274 -0.111
#
# [1000 rows x 15 columns]

# %%
import pandas as pd
import numpy as np

def normalize(series):
    """将数据归一化到0-1范围"""
    return (series - series.min()) / (series.max() - series.min())

def phase_separation_score(df):
    """计算相分离综合得分"""
    # 创建归一化列
    df['norm_nu'] = normalize(1 - df['nuSVR'])
    df['norm_kappa'] = normalize(df['kappa'])
    df['norm_SCD'] = normalize(df['SCD'])
    df['norm_faro'] = normalize(df['faro'])
    df['norm_Sconf'] = normalize(1 - df['SconfSVR/N'])

    # 计算加权得分
    df['phase_sep_score'] = (
        0.35 * df['norm_nu'] +
        0.25 * df['norm_kappa'] +
        0.20 * df['norm_SCD'] +
        0.15 * df['norm_faro'] +
        0.05 * df['norm_Sconf']
    )

    return df

# 使用示例
df = pd.read_csv('svr_pred.csv')
df_with_scores = phase_separation_score(df)
# 高分表示更高的相分离倾向
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SconfSVR/N'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-781dc78408f3> in <cell line: 0>()
#      28 # 使用示例
#      29 df = pd.read_csv('svr_pred.csv')
# ---> 30 df_with_scores = phase_separation_score(df)
#      31 # 高分表示更高的相分离倾向
#
# <ipython-input-11-781dc78408f3> in phase_separation_score(df)
#      13     df['norm_SCD'] = normalize(df['SCD'])
#      14     df['norm_faro'] = normalize(df['faro'])
# ---> 15     df['norm_Sconf'] = normalize(1 - df['SconfSVR/N'])
#      16
#      17     # 计算加权得分
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'SconfSVR/N'
